# %%
# %load_ext autoreload
# %autoreload 2

# %cd ../
# Out:
# /Users/macos/Uni/1st_year/IntroDS/mini_project

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
plt.style.use("seaborn-v0_8")
plt.rcParams.update({'font.size': 8})

# %% [markdown]
# ### More information about the datasets
# 1. **global-data-on-sustainable-energy.csv**: 20-year Insights on Sustainable Energy across the world [URL](https://www.kaggle.com/datasets/anshtanwar/global-data-on-sustainable-energy)
# 2. **API_EG.FEC.RNEW.ZS_DS2_en_csv_v2_5729390.csv**: Rrenewable energy consumption [URL](https://data.worldbank.org/indicator/EG.FEC.RNEW.ZS)

# %% [markdown]
# ## Global sustainable energy

# %%
df_sus = pd.read_csv("data/global-data-on-sustainable-energy.csv")

# %%
df_sus.head(10)
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
# 5  Afghanistan  2005                                25.390894
# 6  Afghanistan  2006                                30.718690
# 7  Afghanistan  2007                                36.051010
# 8  Afghanistan  2008                                42.400000
# 9  Afghanistan  2009                                46.740050
#
#    Access to clean fuels for cooking  \
# 0                               6.20
# 1                               7.20
# 2                               8.20
# 3                               9.50
# 4                              10.90
# 5                              12.20
# ...

# %%
df_sus.columns
# Out:
# Index(['Entity', 'Year', 'Access to electricity (% of population)',
#        'Access to clean fuels for cooking',
#        'Renewable-electricity-generating-capacity-per-capita',
#        'Financial flows to developing countries (US $)',
#        'Renewable energy share in the total final energy consumption (%)',
#        'Electricity from fossil fuels (TWh)', 'Electricity from nuclear (TWh)',
#        'Electricity from renewables (TWh)',
#        'Low-carbon electricity (% electricity)',
#        'Primary energy consumption per capita (kWh/person)',
#        'Energy intensity level of primary energy (MJ/$2017 PPP GDP)',
#        'Value_co2_emissions_kt_by_country',
#        'Renewables (% equivalent primary energy)', 'gdp_growth',
#        'gdp_per_capita', 'Density\n(P/Km2)', 'Land Area(Km2)', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
len(df_sus['Entity'].unique())
# Out:
# 176

# %%
col_renew = "Electricity from renewables (TWh)"
col_renew_per = "Renewable energy share in the total final energy consumption (%)"
col_fos = "Electricity from fossil fuels (TWh)"
col_market_pot = "Renewable-electricity-generating-capacity-per-capita"

# %%
df_sus[['Entity', 'Year', col_market_pot]]
# Out:
#            Entity  Year  Renewable-electricity-generating-capacity-per-capita
# 0     Afghanistan  2000                                               9.22
# 1     Afghanistan  2001                                               8.86
# 2     Afghanistan  2002                                               8.47
# 3     Afghanistan  2003                                               8.09
# 4     Afghanistan  2004                                               7.75
# ...           ...   ...                                                ...
# 3644     Zimbabwe  2016                                              62.88
# 3645     Zimbabwe  2017                                              62.33
# 3646     Zimbabwe  2018                                              82.53
# 3647     Zimbabwe  2019                                              81.40
# 3648     Zimbabwe  2020                                              80.61
#
# [3649 rows x 3 columns]

# %%
fig.savefig("hist.pdf", format='pdf', bbox_inches='tight')

# %%
a
# Out:
# array([1.48671951e-06, 1.49417098e-06, 1.50165829e-06, ...,
#        1.50918161e-06, 1.50165829e-06, 1.49417098e-06])

# %%
norm().pdf(-1)
# Out:
# 0.24197072451914337

# %%
norm().pdf(np.arange(start=-5000, stop=5000, step=0.1))
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
df_renew = df_sus[['Entity', 'Year', col_renew]]

df_renew.head()
# Out:
#         Entity  Year  Electricity from renewables (TWh)
# 0  Afghanistan  2000                               0.31
# 1  Afghanistan  2001                               0.50
# 2  Afghanistan  2002                               0.56
# 3  Afghanistan  2003                               0.63
# 4  Afghanistan  2004                               0.56

# %%
df_renew_pivot = df_renew.pivot(index='Year', columns='Entity', values=col_renew)
df_renew_pivot.head(10)
# Out:
# Entity  Afghanistan  Albania  Algeria  Angola  Antigua and Barbuda  Argentina  \
# Year
# 2000           0.31     4.55     0.05    0.90                  0.0      28.89
# 2001           0.50     3.52     0.07    1.01                  0.0      37.04
# 2002           0.56     3.48     0.06    1.13                  0.0      36.06
# 2003           0.63     5.12     0.26    1.23                  0.0      34.38
# 2004           0.56     5.41     0.25    1.73                  0.0      31.03
# 2005           0.59     5.32     0.55    2.20                  0.0      34.60
# 2006           0.64     4.95     0.22    2.64                  0.0      38.67
# 2007           0.75     2.76     0.22    2.47                  0.0      31.18
# 2008           0.54     3.76     0.28    3.10                  0.0      31.28
# 2009           0.78     5.20     0.30    3.06                  0.0      34.70
#
# Entity  Armenia  Aruba  Australia  Austria  ...  Ukraine  \
# ...

# %%
fig = plt.figure(figsize=(30, 30))
ax = fig.add_subplot(111)


sns.lineplot(data=df_renew_pivot, ax=ax)
# Out:
# <Axes: xlabel='Year'>

# %%
tmp = df_renew[df_renew['Year'] == 2020]
tmp.iloc[tmp[col_renew].argmax()]
# Out:
# Entity                                 China
# Year                                    2020
# Electricity from renewables (TWh)    2184.94
# Name: 734, dtype: object

# %%
tmp.loc[tmp[col_renew].sort_values(ascending=False)[:10].index]
# Out:
#               Entity  Year  Electricity from renewables (TWh)
# 734            China  2020                            2184.94
# 3522   United States  2020                             821.40
# 503           Brazil  2020                             520.01
# 629           Canada  2020                             429.24
# 1554           India  2020                             315.76
# 1302         Germany  2020                             251.48
# 1701           Japan  2020                             205.60
# 2492          Norway  2020                             152.09
# 3501  United Kingdom  2020                             131.74
# 3375          Turkey  2020                             128.34

# %% [markdown]
# ## Read file API

# %%
df_fec = pd.read_csv("data/API_EG.FEC.RNEW.ZS_DS2_en_csv_v2_5729390/API_EG.FEC.RNEW.ZS_DS2_en_csv_v2_5729390.csv")

# %%
df_fec.head(10)
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
# 5                      Albania          ALB
# 6                      Andorra          AND
# 7                   Arab World          ARB
# 8         United Arab Emirates          ARE
# 9                    Argentina          ARG
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
# 1  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
# 2  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
# 3  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
# 4  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS   NaN
# ...

# %%
df_fec.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            0 non-null      float64
#  5   1961            0 non-null      float64
#  6   1962            0 non-null      float64
#  7   1963            0 non-null      float64
#  8   1964            0 non-null      float64
#  9   1965            0 non-null      float64
#  10  1966            0 non-null      float64
#  11  1967            0 non-null      float64
#  12  1968            0 non-null      float64
#  13  1969            0 non-null      float64
#  14  1970            0 non-null      float64
#  15  1971            0 non-null      float64
#  16  1972            0 non-null      float64
# ...

# %%
df_fec['Country Name'].unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'American Samoa', 'Antigua and Barbuda', 'Australia', 'Austria',
#        'Azerbaijan', 'Burundi', 'Belgium', 'Benin', 'Burkina Faso',
#        'Bangladesh', 'Bulgaria', 'Bahrain', 'Bahamas, The',
#        'Bosnia and Herzegovina', 'Belarus', 'Belize', 'Bermuda',
#        'Bolivia', 'Brazil', 'Barbados', 'Brunei Darussalam', 'Bhutan',
#        'Botswana', 'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Channel Islands',
#        'Chile', 'China', "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.',
#        'Congo, Rep.', 'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
# ...
